# %%
import pandas as pd
import numpy as np

# %%
data_name = 'TwoStage'
num_params = 6

if data_name == 'TwoStage':
    df_cols = ['C1', 'WNOUT', 'WPOUT', 'WCS', 'WN1', 'WP1', 'Bandwidth', 'Power Consumption', 'Voltage Gain']
elif data_name == 'LNA':
    df_cols = ['C1', 'C2', 'Ld', 'Lg', 'Ls', 'WN1', 'WN2', 'GT', 'S11', 'NF', 'Bandwidth', 'Power Consumption']
elif data_name == 'SingleStageAmplifier':
    df_cols = ['VDD', 'Vgate', 'Wn', 'Rd', 'Bandwidth', 'Power Consumption', 'Voltage Gain']
elif data_name == 'Cascode':
    df_cols = ['Wbias', 'Rd', 'Wn1', 'Wn2', 'Bandwidth', 'Power Consumption', 'Voltage Gain']
elif data_name == 'VCO':
    df_cols = ['C1', 'L1', 'Rp', 'Wn', 'Wn5', 'Wn6', 'Wvar', 'Oscillation Frequency', 'Power Consumption', 'Output Power', 'Phase Noise', 'Tuning Range']
elif data_name == 'Mixer':
    df_cols = ['C', 'R', 'WLO' , 'WRF', 'Power Consumption', 'IF Voltage Swing', 'Conversion Gain' , 'Noise Figure']
elif data_name == 'PA':
    df_cols = ['L1p', 'L1s', 'L3p', 'L3s', 'Lm', 'Wn1', 'Wn2', 'S11', 'S22', 'Large Signal Power Gain', 'PAE', 'Drain Efficiency', 'PSAT', 'Power Consumption']
else:
    raise ValueError("No Dataset Found with This Name!")

# %%
data = pd.read_csv(f'data/{data_name}/{data_name}.csv')

x = np.asarray(data.iloc[:,0:num_params])
np.save(f'data/{data_name}/x.npy', x)

y = np.asarray(data.iloc[:,num_params:])
np.save(f'data/{data_name}/y.npy', y)

# %%
def make_csv_results(data_name, df_cols, type):
    
    df = pd.DataFrame(columns=df_cols)

    x = np.load(f'data/{data_name}/{type}_x.npy')
    y = np.load(f'data/{data_name}/{type}_y.npy')

    for i in range(x.shape[0]):
        df.loc[i] = list(x[i]) + list(y[i])

    df.to_csv(f'data/{data_name}/{type}_{data_name}.csv', index=False)
    return df

# %%
make_csv_results(data_name, df_cols, 'test')
# Out:
#                 C1     WNOUT     WPOUT       WCS       WN1       WP1  \
# 0     2.486248e-13  0.000003  0.000004  0.000005  0.000003  0.000003
# 1     1.514623e-13  0.000002  0.000003  0.000006  0.000003  0.000004
# 2     2.466649e-13  0.000001  0.000003  0.000004  0.000003  0.000003
# 3     2.493694e-13  0.000002  0.000002  0.000005  0.000004  0.000004
# 4     1.515815e-13  0.000001  0.000002  0.000005  0.000003  0.000004
# ...            ...       ...       ...       ...       ...       ...
# 1924  1.682090e-13  0.000004  0.000004  0.000005  0.000004  0.000003
# 1925  1.503814e-13  0.000003  0.000004  0.000006  0.000003  0.000004
# 1926  1.510803e-13  0.000002  0.000005  0.000005  0.000004  0.000005
# 1927  2.464684e-13  0.000005  0.000004  0.000005  0.000002  0.000003
# 1928  1.998477e-13  0.000005  0.000004  0.000005  0.000003  0.000004
#
#         Bandwidth  Power Consumption  Voltage Gain
# 0      54200000.0             0.0480         21.47
# 1     169000000.0             0.0338         17.30
# 2      78400000.0             0.0209         20.99
# 3     124000000.0             0.0325         18.06
# 4     149000000.0             0.0213         19.68
# ...           ...                ...           ...
# 1924   88200000.0             0.0610         19.53
# 1925  181000000.0             0.0474         17.60
# 1926  157000000.0             0.0213         21.36
# 1927   30200000.0             0.0611         24.04
# 1928  142000000.0             0.0591         16.81
#
# [1929 rows x 9 columns]

# %%
make_csv_results(data_name, df_cols, 'train')
# Out:
#                  C1     WNOUT     WPOUT       WCS       WN1       WP1  \
# 0      2.163765e-13  0.000002  0.000002  0.000005  0.000003  0.000003
# 1      2.510542e-13  0.000003  0.000003  0.000004  0.000003  0.000004
# 2      2.502277e-13  0.000005  0.000001  0.000004  0.000004  0.000004
# 3      2.507751e-13  0.000003  0.000004  0.000004  0.000004  0.000004
# 4      2.478541e-13  0.000002  0.000003  0.000004  0.000003  0.000003
# ...             ...       ...       ...       ...       ...       ...
# 17356  1.674702e-13  0.000003  0.000002  0.000005  0.000003  0.000004
# 17357  2.357092e-13  0.000002  0.000004  0.000006  0.000003  0.000004
# 17358  2.486877e-13  0.000004  0.000003  0.000005  0.000003  0.000004
# 17359  2.263174e-13  0.000001  0.000004  0.000005  0.000003  0.000003
# 17360  2.247410e-13  0.000002  0.000003  0.000006  0.000003  0.000004
#
#          Bandwidth  Power Consumption  Voltage Gain
# 0       22000000.0             0.0224         33.28
# 1       98300000.0             0.0458         18.15
# 2      108000000.0             0.0565         16.70
# 3       97900000.0             0.0462         18.74
# 4       48900000.0             0.0349         22.32
# ...            ...                ...           ...
# 17356  139000000.0             0.0453         14.80
# 17357   53200000.0             0.0225         27.04
# 17358  114000000.0             0.0457         17.93
# 17359   67600000.0             0.0218         24.04
# 17360  116000000.0             0.0339         17.55
#
# [17361 rows x 9 columns]
